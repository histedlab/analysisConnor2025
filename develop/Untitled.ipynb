# %%
import numpy as np
import matplotlib as mpl; import matplotlib.pyplot as plt;
test = np.load('C:\\Users\\Connor\\data-local\\data-to-delete\\pre\\trial_dfoFtrace_pre_lseg.npy')

# %%
test.shape
# Out:
# (387, 16, 140)

# %%
plt.plot(test[0,1,0:139])
